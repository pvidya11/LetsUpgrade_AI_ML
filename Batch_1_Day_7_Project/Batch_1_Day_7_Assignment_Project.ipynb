# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### To load the dataset :

# %%
dataset1=pd.read_csv(r"G:\study_vidya\LetsUPgrade\1_AI_ML_Course\Project_01\general_data.csv")

# %% [markdown]
# #### To view first few rows of data:

# %%
dataset1.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  \
# 0          2  Life Sciences              1           1  Female
# 1          1  Life Sciences              1           2  Female
# 2          4          Other              1           3    Male
# 3          5  Life Sciences              1           4    Male
# 4          1        Medical              1           5    Male
#
#            ...           NumCompaniesWorked Over18 PercentSalaryHike  \
# ...

# %% [markdown]
# #### To check the column names:

# %%
dataset1.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ## 2: Data Treatment
# #### To check if there are any null values in the dataset:

# %%
dataset1.isnull()
# Out:
#         Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0     False      False           False       False             False
# 1     False      False           False       False             False
# 2     False      False           False       False             False
# 3     False      False           False       False             False
# 4     False      False           False       False             False
# 5     False      False           False       False             False
# 6     False      False           False       False             False
# 7     False      False           False       False             False
# 8     False      False           False       False             False
# 9     False      False           False       False             False
# 10    False      False           False       False             False
# 11    False      False           False       False             False
# 12    False      False           False       False             False
# ...

# %% [markdown]
# #### To check if there are any duplicate values:

# %%
dataset1.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 4380    False
# 4381    False
# 4382    False
# 4383    False
# 4384    False
# 4385    False
# 4386    False
# 4387    False
# 4388    False
# 4389    False
# 4390    False
# 4391    False
# 4392    False
# 4393    False
# 4394    False
# 4395    False
# 4396    False
# 4397    False
# 4398    False
# 4399    False
# 4400    False
# 4401    False
# 4402    False
# 4403    False
# 4404    False
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# ...

# %% [markdown]
# #### To remove duplicate values(if any):

# %%
dataset1.drop_duplicates()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# 5      46        No      Travel_Rarely  Research & Development
# 6      28       Yes      Travel_Rarely  Research & Development
# 7      29        No      Travel_Rarely  Research & Development
# 8      31        No      Travel_Rarely  Research & Development
# 9      25        No         Non-Travel  Research & Development
# 10     45        No      Travel_Rarely  Research & Development
# 11     36        No      Travel_Rarely  Research & Development
# 12     55        No      Travel_Rarely  Research & Development
# 13     47       Yes         Non-Travel  Research & Development
# ...

# %% [markdown]
# #### To check dataset info:

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 24 columns):
# Age                        4410 non-null int64
# Attrition                  4410 non-null object
# BusinessTravel             4410 non-null object
# Department                 4410 non-null object
# DistanceFromHome           4410 non-null int64
# Education                  4410 non-null int64
# EducationField             4410 non-null object
# EmployeeCount              4410 non-null int64
# EmployeeID                 4410 non-null int64
# Gender                     4410 non-null object
# JobLevel                   4410 non-null int64
# JobRole                    4410 non-null object
# MaritalStatus              4410 non-null object
# MonthlyIncome              4410 non-null int64
# NumCompaniesWorked         4391 non-null float64
# Over18                     4410 non-null object
# PercentSalaryHike          4410 non-null int64
# ...

# %% [markdown]
# ## 3 – Univariate Analysis:

# %% [markdown]
# #### Describing the entire dataset:

# %%
dataset1.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %%
dataset1[["Age","DistanceFromHome","Education","MonthlyIncome","NumCompaniesWorked","PercentSalaryHike","TotalWorkingYears",
          "TrainingTimesLastYear","YearsAtCompany","YearsSinceLastPromotion","YearsWithCurrManager"]]
# Out:
#       Age  DistanceFromHome  Education  MonthlyIncome  NumCompaniesWorked  \
# 0      51                 6          2         131160                 1.0
# 1      31                10          1          41890                 0.0
# 2      32                17          4         193280                 1.0
# 3      38                 2          5          83210                 3.0
# 4      32                10          1          23420                 4.0
# 5      46                 8          3          40710                 3.0
# 6      28                11          2          58130                 2.0
# 7      29                18          3          31430                 2.0
# 8      31                 1          3          20440                 0.0
# 9      25                 7          4         134640                 1.0
# 10     45                17          2          79910                 0.0
# 11     36                28          1          33770                 0.0
# ...

# %% [markdown]
# ####  To find the median:

# %%
median_series=dataset1[["Age","DistanceFromHome","Education","MonthlyIncome","NumCompaniesWorked","PercentSalaryHike",
                        "TotalWorkingYears","TrainingTimesLastYear","YearsAtCompany","YearsSinceLastPromotion",
                        "YearsWithCurrManager"]].median()
median_series
# Out:
# Age                           36.0
# DistanceFromHome               7.0
# Education                      3.0
# MonthlyIncome              49190.0
# NumCompaniesWorked             2.0
# PercentSalaryHike             14.0
# TotalWorkingYears             10.0
# TrainingTimesLastYear          3.0
# YearsAtCompany                 5.0
# YearsSinceLastPromotion        1.0
# YearsWithCurrManager           3.0
# dtype: float64

# %% [markdown]
# ####  To find the mode:

# %%
mode_series=dataset1[["Age","DistanceFromHome","Education","MonthlyIncome","NumCompaniesWorked","PercentSalaryHike",
                        "TotalWorkingYears","TrainingTimesLastYear","YearsAtCompany","YearsSinceLastPromotion",
                        "YearsWithCurrManager"]].mode()
mode_series
# Out:
#    Age  DistanceFromHome  Education  MonthlyIncome  NumCompaniesWorked  \
# 0   35                 2          3          23420                 1.0
#
#    PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 11               10.0                      2
#
#    YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager
# 0               5                        0                     2

# %% [markdown]
# #### To find mean:

# %%
mean_series=dataset1[["Age","DistanceFromHome","Education","MonthlyIncome","NumCompaniesWorked","PercentSalaryHike",
                        "TotalWorkingYears","TrainingTimesLastYear","YearsAtCompany","YearsSinceLastPromotion",
                        "YearsWithCurrManager"]].mean()
mean_series
# Out:
# Age                           36.923810
# DistanceFromHome               9.192517
# Education                      2.912925
# MonthlyIncome              65029.312925
# NumCompaniesWorked             2.694830
# PercentSalaryHike             15.209524
# TotalWorkingYears             11.279936
# TrainingTimesLastYear          2.799320
# YearsAtCompany                 7.008163
# YearsSinceLastPromotion        2.187755
# YearsWithCurrManager           4.123129
# dtype: float64

# %% [markdown]
# #### To find variance:

# %%
var_series=dataset1[["Age","DistanceFromHome","Education","MonthlyIncome","NumCompaniesWorked","PercentSalaryHike",
                        "TotalWorkingYears","TrainingTimesLastYear","YearsAtCompany","YearsSinceLastPromotion",
                        "YearsWithCurrManager"]].var()
var_series
# Out:
# Age                        8.341719e+01
# DistanceFromHome           6.569144e+01
# Education                  1.048438e+00
# MonthlyIncome              2.215480e+09
# NumCompaniesWorked         6.244436e+00
# PercentSalaryHike          1.338907e+01
# TotalWorkingYears          6.056298e+01
# TrainingTimesLastYear      1.661465e+00
# YearsAtCompany             3.751728e+01
# YearsSinceLastPromotion    1.037935e+01
# YearsWithCurrManager       1.272582e+01
# dtype: float64

# %% [markdown]
# #### To find skew:

# %%
skew_series=dataset1[["Age","DistanceFromHome","Education","MonthlyIncome","NumCompaniesWorked","PercentSalaryHike",
                        "TotalWorkingYears","TrainingTimesLastYear","YearsAtCompany","YearsSinceLastPromotion",
                        "YearsWithCurrManager"]].skew()
skew_series
# Out:
# Age                        0.413005
# DistanceFromHome           0.957466
# Education                 -0.289484
# MonthlyIncome              1.368884
# NumCompaniesWorked         1.026767
# PercentSalaryHike          0.820569
# TotalWorkingYears          1.116832
# TrainingTimesLastYear      0.552748
# YearsAtCompany             1.763328
# YearsSinceLastPromotion    1.982939
# YearsWithCurrManager       0.832884
# dtype: float64

# %% [markdown]
# #### To find kurtosis:

# %%
kurt_series=dataset1[["Age","DistanceFromHome","Education","MonthlyIncome","NumCompaniesWorked","PercentSalaryHike",
                        "TotalWorkingYears","TrainingTimesLastYear","YearsAtCompany","YearsSinceLastPromotion",
                        "YearsWithCurrManager"]].kurt()
kurt_series
# Out:
# Age                       -0.405951
# DistanceFromHome          -0.227045
# Education                 -0.560569
# MonthlyIncome              1.000232
# NumCompaniesWorked         0.007287
# PercentSalaryHike         -0.302638
# TotalWorkingYears          0.912936
# TrainingTimesLastYear      0.491149
# YearsAtCompany             3.923864
# YearsSinceLastPromotion    3.601761
# YearsWithCurrManager       0.167949
# dtype: float64

# %% [markdown]
# #### To find standard deviation:

# %%
std_series=dataset1[["Age","DistanceFromHome","Education","MonthlyIncome","NumCompaniesWorked","PercentSalaryHike",
                        "TotalWorkingYears","TrainingTimesLastYear","YearsAtCompany","YearsSinceLastPromotion",
                        "YearsWithCurrManager"]].std()
std_series
# Out:
# Age                            9.133301
# DistanceFromHome               8.105026
# Education                      1.023933
# MonthlyIncome              47068.888559
# NumCompaniesWorked             2.498887
# PercentSalaryHike              3.659108
# TotalWorkingYears              7.782222
# TrainingTimesLastYear          1.288978
# YearsAtCompany                 6.125135
# YearsSinceLastPromotion        3.221699
# YearsWithCurrManager           3.567327
# dtype: float64

# %%
df =pd.concat([mean_series,median_series,mode_series.iloc[0],var_series,std_series,skew_series,kurt_series],axis=1,sort=False)
df.columns=["Mean",'Median',"Mode","Variance","Standard_Deviation","Skew","Kurtosis"]
df
# Out:
#                                  Mean   Median     Mode      Variance  \
# Age                         36.923810     36.0     35.0  8.341719e+01
# DistanceFromHome             9.192517      7.0      2.0  6.569144e+01
# Education                    2.912925      3.0      3.0  1.048438e+00
# MonthlyIncome            65029.312925  49190.0  23420.0  2.215480e+09
# NumCompaniesWorked           2.694830      2.0      1.0  6.244436e+00
# PercentSalaryHike           15.209524     14.0     11.0  1.338907e+01
# TotalWorkingYears           11.279936     10.0     10.0  6.056298e+01
# TrainingTimesLastYear        2.799320      3.0      2.0  1.661465e+00
# YearsAtCompany               7.008163      5.0      5.0  3.751728e+01
# YearsSinceLastPromotion      2.187755      1.0      0.0  1.037935e+01
# YearsWithCurrManager         4.123129      3.0      2.0  1.272582e+01
#
#                          Standard_Deviation      Skew  Kurtosis
# ...

# %% [markdown]
# From table above, we can conclude that :
#
#     All the features have positive skewness (since mean > median), except Education has negative skewness, but age seems like normal dist since the difference between mean and median is not too far.
#
#     Age, Distance from home, education, percentsalaryhike have minus Kurt so it has Platykurtic, NumComWorked near to zero so it can Mesokuartic, and the other feature have Laptokuart

# %% [markdown]
# #### Outliers:
#     There’s no regression found while plotting Age, MonthlyIncome, TotalWorkingYears, YearsAtCompany, etc.,on a scatter plot.

# %%
plt.boxplot(dataset1.Age)
plt.title("Box Plot of Age")
plt.show()

# %%
lst=["Age","DistanceFromHome","Education","MonthlyIncome","PercentSalaryHike",
     "TrainingTimesLastYear","YearsAtCompany","YearsSinceLastPromotion","YearsWithCurrManager"]
for i in lst:
    print(i,":- ")
    if dataset1[i].skew() > 0 :
        print(i," data is Positive Skewed Distribution.")
    elif  dataset1[i].skew() < 0 :
        print(i," Data is Negative Skewed Distribution.")
    elif dataset1[i].skew() == 0 :
        print(i, " Data is Normally Distributed.")
    else:
        print(i, " Data Something Missing.")
    plt.boxplot(dataset1[i])
    plt.title("Box plot of {0} for checking outliers.".format(i))
    plt.show()
    print("------------------------------------------ \n")
# Out:
# Age :-
# Age  data is Positive Skewed Distribution.
# ------------------------------------------
#
# DistanceFromHome :-
# DistanceFromHome  data is Positive Skewed Distribution.
# ------------------------------------------
#
# Education :-
# Education  Data is Negative Skewed Distribution.
# ------------------------------------------
#
# MonthlyIncome :-
# MonthlyIncome  data is Positive Skewed Distribution.
# ------------------------------------------
#
# PercentSalaryHike :-
# PercentSalaryHike  data is Positive Skewed Distribution.
# ------------------------------------------
#
# TrainingTimesLastYear :-
# TrainingTimesLastYear  data is Positive Skewed Distribution.
# ------------------------------------------
#
# YearsAtCompany :-
# YearsAtCompany  data is Positive Skewed Distribution.
# ------------------------------------------
#
# YearsSinceLastPromotion :-
# YearsSinceLastPromotion  data is Positive Skewed Distribution.
# ------------------------------------------
#
# ...

# %%
for i in lst:
    print(i)
    x=pd.Series(sorted(dataset1[i]))
    plt.scatter(x.index,x)
    plt.show()
# Out:
# Age
# DistanceFromHome
# Education
# MonthlyIncome
# PercentSalaryHike
# TrainingTimesLastYear
# YearsAtCompany
# YearsSinceLastPromotion
# YearsWithCurrManager

# %%
#plt.scatter(dataset1.Age,dataset1.Age)
#plt.scatter(
lst=["Age","DistanceFromHome","Education","MonthlyIncome","PercentSalaryHike",
     "TrainingTimesLastYear","YearsAtCompany","YearsSinceLastPromotion","YearsWithCurrManager"]
for i in lst:
    print(i)
    count_data=dataset1[i].value_counts().sort_index()
    plt.scatter(count_data.index,y=count_data)
    plt.show()
# Out:
# Age
# DistanceFromHome
# Education
# MonthlyIncome
# PercentSalaryHike
# TrainingTimesLastYear
# YearsAtCompany
# YearsSinceLastPromotion
# YearsWithCurrManager

# %% [markdown]
# ## Step 4 : Visualization

# %%
import seaborn as sns
g = sns.catplot("Department", col="Attrition",
                data=dataset1[['Department',"Attrition"]],
                kind="count", height=4.5, aspect=1)
#plt.figure(figsize=(16,10), dpi= 80)
g.set_xticklabels(rotation=10)
plt.show()

# %%
g = sns.catplot("EducationField", col="Attrition",
                data=dataset1[['EducationField',"Attrition"]],
                kind="count", height=4.5, aspect=1)
#plt.figure(figsize=(16,10), dpi= 80)
g.set_xticklabels(rotation=20)
plt.show()

# %% [markdown]
# ## Step 5 : Statistical Tests [Non-Paramatric]
#     1. chi2_contingency Test:

# %%
dataset1.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  \
# 0          2  Life Sciences              1           1  Female
# 1          1  Life Sciences              1           2  Female
# 2          4          Other              1           3    Male
# 3          5  Life Sciences              1           4    Male
# 4          1        Medical              1           5    Male
#
#            ...           NumCompaniesWorked Over18 PercentSalaryHike  \
# ...

# %%
dataset1.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
dataset1.dropna()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# 5      46        No      Travel_Rarely  Research & Development
# 6      28       Yes      Travel_Rarely  Research & Development
# 7      29        No      Travel_Rarely  Research & Development
# 8      31        No      Travel_Rarely  Research & Development
# 9      25        No         Non-Travel  Research & Development
# 10     45        No      Travel_Rarely  Research & Development
# 11     36        No      Travel_Rarely  Research & Development
# 12     55        No      Travel_Rarely  Research & Development
# 13     47       Yes         Non-Travel  Research & Development
# ...

# %%
from scipy.stats import chi2_contingency

'H0 - There is no dependency between Attrition and Age (REJECTED)'
'H1 - There is dependency between Attrition and Age'

chitable = pd.crosstab(dataset1.Attrition, dataset1.Age)

stats1, p1, dof1, expected1 = chi2_contingency(chitable)
print(stats1, p1)


if p1 < 0.05 :
    print("We reject the Ho")
else:
    print("We Accept the Ho")
# in the result below we can say that we reject the Ho due to p < 0.05
# Out:
# 357.52484648609584 1.1886524349105674e-51
# We reject the Ho

# %%
'H0 - There is no dependency between Attrition and Gender (ACCEPTED)'
'H1 - There is dependency between Attrition and Gender'

chitable2 = pd.crosstab(dataset1.Attrition, dataset1.Gender)

stats2, p2, dof2, expected2 = chi2_contingency(chitable2)
print(stats2, p2)

if p2 < 0.05 :
    print("We reject the Ho")
else:
    print("We Accept the Ho")
# in the result below we can say that we accept the Ho due to p > 0.05
# Out:
# 1.349904410246582 0.24529482862926827
# We Accept the Ho

# %%
'H0 - There is no dependency between Attrition and JobLevel   (ACCEPTED)'
'H1 - There is dependency between Attrition and JobLevel  '

chitable2 = pd.crosstab(dataset1.Attrition, dataset1.JobLevel )

stats2, p2, dof2, expected2 = chi2_contingency(chitable2)
print(stats2, p2)

if p2 < 0.05 :
    print("We reject the Ho")
else:
    print("We Accept the Ho")
# in the result below we can say that we accept the Ho due to p > 0.05
# Out:
# 6.2691759264759925 0.1799276801337184
# We Accept the Ho

# %%
'H0 - There is no dependency between Attrition and Education (ACCEPTED)'
'H1 - There is dependency between Attrition and Education   '

chitable2 = pd.crosstab(dataset1.Attrition, dataset1.Education  )

stats2, p2, dof2, expected2 = chi2_contingency(chitable2)
print(stats2, p2)

if p2 < 0.05 :
    print("We reject the Ho")
else:
    print("We Accept the Ho")
# in the result below we can say that we accept the Ho due to p > 0.05
# Out:
# 5.6411476792491975 0.22759826301782404
# We Accept the Ho

# %%
'H0 - There is no dependency between Attrition and NumCompaniesWorked (REJECTED)'
'H1 - There is dependency between Attrition and NumCompaniesWorked   '

chitable2 = pd.crosstab(dataset1.Attrition, dataset1.NumCompaniesWorked  )

stats2, p2, dof2, expected2 = chi2_contingency(chitable2)
print(stats2, p2)

if p2 < 0.05 :
    print("We reject the Ho")
else:
    print("We Accept the Ho")
# in the result below we can say that we accept the Ho due to p > 0.05
# Out:
# 75.19096213171483 1.4488734771666454e-12
# We reject the Ho

# %%
'H0 - There is no dependency between Attrition and TotalWorkingYears  (REJECTED)'
'H1 - There is dependency between Attrition and TotalWorkingYears    '

chitable2 = pd.crosstab(dataset1.Attrition, dataset1.NumCompaniesWorked  )

stats2, p2, dof2, expected2 = chi2_contingency(chitable2)
print(stats2, p2)

if p2 < 0.05 :
    print("We reject the Ho")
else:
    print("We Accept the Ho")
# in the result below we can say that we accept the Ho due to p > 0.05
# Out:
# 75.19096213171483 1.4488734771666454e-12
# We reject the Ho

# %%
'H0 - There is no dependency between Attrition and PercentSalaryHike (ACCEPTED)'
'H1 - There is dependency between Attrition and PercentSalaryHike   '

chitable2 = pd.crosstab(dataset1.Attrition, dataset1.PercentSalaryHike  )

stats2, p2, dof2, expected2 = chi2_contingency(chitable2)
print(stats2, p2)

if p2 < 0.05 :
    print("We reject the Ho")
else:
    print("We Accept the Ho")
# in the result below we can say that we accept the Ho due to p > 0.05
# Out:
# 19.134303440424052 0.15988066739973142
# We Accept the Ho

# %%
'H0 - There is no dependency between Attrition and YearsAtCompany (REJECTED)'
'H1 - There is dependency between Attrition and YearsAtCompany   '

chitable2 = pd.crosstab(dataset1.Attrition, dataset1.YearsAtCompany  )

stats2, p2, dof2, expected2 = chi2_contingency(chitable2)
print(stats2, p2)

if p2 < 0.05 :
    print("We reject the Ho")
else:
    print("We Accept the Ho")
# in the result below we can say that we accept the Ho due to p > 0.05
# Out:
# 286.16626478262043 1.0190499837423921e-40
# We reject the Ho

# %%
'H0 - There is no dependency between Attrition and YearsSinceLastPromotion (REJECTED)'
'H1 - There is dependency between Attrition and YearsSinceLastPromotion    '

chitable2 = pd.crosstab(dataset1.Attrition, dataset1.YearsSinceLastPromotion)

stats2, p2, dof2, expected2 = chi2_contingency(chitable2)
print(stats2, p2)

if p2 < 0.05 :
    print("We reject the Ho")
else:
    print("We Accept the Ho")
# in the result below we can say that we accept the Ho due to p > 0.05
# Out:
# 65.53490981436207 2.7530023754864334e-08
# We reject the Ho

# %%
'H0 - There is no dependency between Attrition and DistanceFromHome  (REJECTED)'
'H1 - There is dependency between Attrition and DistanceFromHome     '

chitable2 = pd.crosstab(dataset1.Attrition, dataset1.DistanceFromHome )

stats2, p2, dof2, expected2 = chi2_contingency(chitable2)
print(stats2, p2)

if p2 < 0.05 :
    print("We reject the Ho")
else:
    print("We Accept the Ho")
# in the result below we can say that we accept the Ho due to p > 0.05
# Out:
# 102.3516705172535 2.098176387479194e-10
# We reject the Ho

# %% [markdown]
# #### Conclusion
# We assume that factors those has dependency with attrition are:
#
# 1. Business Travel, we can see, many leaving employee are rarely traveling
# 2. Monthly income, those have income < $25000 are leaving the company
# 3. YearSinceLastPromotion, we can see that we reject the null hypotesis, it means there is dependency between attrition and  this feature
# 4. Distancefromhome, from the hypotesis test, we rejected the Null Hypothesis, it means there is a dependency between attrition and this feature and also from the visualization. Employee that has short distance likely leaves the company.
